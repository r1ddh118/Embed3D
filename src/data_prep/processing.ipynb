# %%
from datasets import load_dataset

# Load the dataset in streaming mode (no full download)
dataset = load_dataset("pmchard/3D-ADAM", split="train", streaming=True)

# Convert to iterable and take only 5%
# If you know the dataset size (e.g., 14,120 samples), 5% = ~706 samples
sample_size = int(14120 * 0.05)

# Take the first 5% items
small_dataset = dataset.take(sample_size)
